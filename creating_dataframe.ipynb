# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

root_path = '/content/drive/MyDrive/Student-Led Project/'

# --- Load GTEx TPM file (skip header lines) ---
tpm_path = root_path + "GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz"
tpm_df = pd.read_csv(tpm_path, sep="\t", skiprows=2)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# ...

# %%
'''
# Strip Ensembl version numbers (e.g., ENSG00000123456.5 → ENSG00000123456)
tpm_df['Name'] = tpm_df['Name'].str.split('.').str[0]
tpm_df = tpm_df.rename(columns={'Name': 'gene_id'})

# --- Load GTEx sample metadata ---
meta_path = "GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt"
meta_df = pd.read_csv(meta_path, sep="\t")

# Pick a tissue (e.g., Liver, Brain - Cortex, Lung)
target_tissue = "Liver"
sample_ids = meta_df[meta_df['SMTSD'] == target_tissue]['SAMPID'].tolist()

# Filter TPM data to include only columns with these samples
columns_to_keep = ['gene_id', 'Description'] + sample_ids
tpm_filtered = tpm_df[columns_to_keep]

# Average TPM per gene across selected samples
tpm_filtered['tpm_mean'] = tpm_filtered[sample_ids].mean(axis=1)

# Keep only gene_id and averaged TPM
tpm_final = tpm_filtered[['gene_id', 'tpm_mean']]

# Save intermediate result (optional)
tpm_final.to_csv(f"GTEx_{target_tissue}_avg_tpm.csv", index=False)

print(f"✅ Processed expression for {len(tpm_final)} genes in {target_tissue}.")
'''
